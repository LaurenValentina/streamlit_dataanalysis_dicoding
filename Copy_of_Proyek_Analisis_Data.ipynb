# %% [markdown]
# # Proyek Analisis Data: [Bike-sharing-dataset"hour.csv"]
# - **Nama:** [Lauren Valentina]
# - **Email:** [lauren2909p@gmail.com]
# - **ID Dicoding:** [lauren_valentina]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Pertanyaan 1
# Bagaimana pola permintaan sewa sepeda dari waktu ke waktu (harian, mingguan, bulanan, musiman)?
# - Pertanyaan 2
# Faktor-faktor apa saja yang mempengaruhi jumlah sewa sepeda (cuaca, hari libur, akhir pekan, jam kerja, dll)?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# - numpy untuk komputasi numerik
# - pandas untuk membaca , memproses, dan menganalisis data
# - matplotlib untuk membuat visualisasu data dalam grafik,plot,histogram,dll.
# - seboron untuk visualisasi data berbasis Matplotlib yang menyediakan antarmuka pemrograman tingkat tinggi dan gaya visual yang menarik.

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
data = pd.read_csv("dasbord/hour.csv")
data.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# ###### menilai data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %% [raw]
# dari jumlah total data tiap kolom nya berjumlah 17379 data menandakan tidak terjadi missing value

# %% [markdown]
# ###### missing value

# %%
data.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [raw]
# Library pandas menyediakan sebuah method bernama isnull() atau isna() untuk mengidentifikasi missing value dalam sebuah DataFrame. Keduanya sering dipadukan dengan method sum()untuk menghitung total missing value pada setiap kolom dalam sebuah DataFrame.
# dari dataset yang kita punya ternyata tidak terdapat missing value

# %% [markdown]
# ###### duplicate data

# %%
data.duplicated().sum()
# Out:
# 0

# %% [raw]
# Pandas menyediakan sebuah method duplicated()untuk mengidentifikasi apakah terdapat duplikasi pada sebuah DataFrame.
# berdasarkan dataset yang kita punya bahwa dia tidak memiliki data yang duplicate(dupilat)

# %% [markdown]
# ###### menilai data

# %%
data.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %% [markdown]
# ### Cleaning Data

# %% [raw]
# pada tahapan cleaning terdapat beberapa cara untuk melakukan nya seperti :
# 1.Dropping
# Metode pertama dan yang paling mudah dalam mengatasi missing value adalah dropping. Pada metode ini, kita akan menghapus seluruh baris atau kolom yang memiliki missing value. Untuk melakukannya, kita bisa menggunakan salah satu method dropna()yang disediakan oleh library pandas.
# 2. Imputation
# Metode lain yang umum digunakan untuk mengatasi missing value ialah metode imputation. Metode ini bekerja dengan cara mengisi (fill) missing value dengan nilai tertentu. Hal ini tentunya akan mencegah hilangnya informasi akibat missing value.
# 3. Interpolation
# Metode penanganan missing value terakhir yang akan kita bahas ialah interpolation (interpolasi). Sederhananya, interpolasi merupakan salah satu pendekatan numerik yang digunakan untuk menghitung titik data baru berdasarkan range data yang sudah ada. Perhitungan ini menggunakan sebuah persamaan garis linear ataupun polynomial. Perhitungan tersebut membuat metode ini sangat cocok digunakan untuk menangani missing value pada data time series.
#
# berdasarkan proses assesing data kita telah mengetahui bahwa dataset yang kita punya tidak memiliki missing value jadi kita tidak perlu melakukan proses cleaning data

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': 'instant'}>,
#         <Axes: title={'center': 'season'}>,
#         <Axes: title={'center': 'yr'}>, <Axes: title={'center': 'mnth'}>],
#        [<Axes: title={'center': 'hr'}>,
#         <Axes: title={'center': 'holiday'}>,
#         <Axes: title={'center': 'weekday'}>,
#         <Axes: title={'center': 'workingday'}>],
#        [<Axes: title={'center': 'weathersit'}>,
#         <Axes: title={'center': 'temp'}>,
#         <Axes: title={'center': 'atemp'}>,
#         <Axes: title={'center': 'hum'}>],
#        [<Axes: title={'center': 'windspeed'}>,
#         <Axes: title={'center': 'casual'}>,
#         <Axes: title={'center': 'registered'}>,
#         <Axes: title={'center': 'cnt'}>]], dtype=object)

# %%
data.corr()
# Out:
# C:\Users\LAUREN VALENTINA\AppData\Local\Temp\ipykernel_216\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#              instant    season        yr      mnth        hr   holiday  \
# instant     1.000000  0.404046  0.866014  0.489164 -0.004775  0.014723
# season      0.404046  1.000000 -0.010742  0.830386 -0.006117 -0.009585
# yr          0.866014 -0.010742  1.000000 -0.010473 -0.003867  0.006692
# mnth        0.489164  0.830386 -0.010473  1.000000 -0.005772  0.018430
# hr         -0.004775 -0.006117 -0.003867 -0.005772  1.000000  0.000479
# holiday     0.014723 -0.009585  0.006692  0.018430  0.000479  1.000000
# weekday     0.001357 -0.002335 -0.004485  0.010400 -0.003498 -0.102088
# workingday -0.003416  0.013743 -0.002196 -0.003477  0.002285 -0.252471
# ...

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %% [raw]
# Bagaimana pola permintaan sewa sepeda dari waktu ke waktu (harian, mingguan, bulanan, musiman)?

# %%
# Menghitung jumlah sewa sepeda per jam
hourly_demand = data.groupby('hr')['cnt'].mean().reset_index()

# Menghitung jumlah sewa sepeda per hari dalam seminggu
daily_demand = data.groupby('weekday')['cnt'].mean().reset_index()

# Menghitung jumlah sewa sepeda per bulan
monthly_demand = data.groupby('mnth')['cnt'].mean().reset_index()

# Menghitung jumlah sewa sepeda per musim
seasonal_demand = data.groupby('season')['cnt'].mean().reset_index()

# Visualisasi pola harian
plt.figure(figsize=(10, 6))
plt.plot(hourly_demand['hr'], hourly_demand['cnt'])
plt.title('Pola Permintaan Sewa Sepeda Harian')
plt.xlabel('Jam')
plt.ylabel('Jumlah Sewa Sepeda')
plt.show()

# Visualisasi pola mingguan
plt.figure(figsize=(10, 6))
plt.bar(daily_demand['weekday'], daily_demand['cnt'])
plt.title('Pola Permintaan Sewa Sepeda Mingguan')
plt.xlabel('Hari dalam Seminggu')
plt.ylabel('Jumlah Sewa Sepeda')
plt.show()

# Visualisasi pola bulanan
plt.figure(figsize=(10, 6))
plt.bar(monthly_demand['mnth'], monthly_demand['cnt'])
plt.title('Pola Permintaan Sewa Sepeda Bulanan')
plt.xlabel('Bulan')
plt.ylabel('Jumlah Sewa Sepeda')
plt.show()

# Visualisasi pola musiman
plt.figure(figsize=(10, 6))
plt.bar(seasonal_demand['season'], seasonal_demand['cnt'])
plt.title('Pola Permintaan Sewa Sepeda Musiman')
plt.xlabel('Musim')
plt.ylabel('Jumlah Sewa Sepeda')
plt.show()

# %% [markdown]
# ### Pertanyaan 2:

# %% [raw]
# Faktor-faktor apa saja yang mempengaruhi jumlah sewa sepeda (cuaca, hari libur, akhir pekan, jam kerja, dll)?

# %%
# Menghitung korelasi antara fitur dan jumlah sewa sepeda
corr = data.corr()['cnt'].drop('cnt')
print("Korelasi antara fitur dan jumlah sewa sepeda:")
print(corr)

# Visualisasi pengaruh cuaca terhadap jumlah sewa sepeda
plt.figure(figsize=(10, 6))
sns.barplot(x='weathersit', y='cnt', data=data)
plt.title('Pengaruh Cuaca terhadap Jumlah Sewa Sepeda')
plt.xlabel('Kondisi Cuaca')
plt.ylabel('Jumlah Sewa Sepeda')
plt.show()

# Visualisasi pengaruh hari libur terhadap jumlah sewa sepeda
plt.figure(figsize=(10, 6))
sns.barplot(x='holiday', y='cnt', data=data)
plt.title('Pengaruh Hari Libur terhadap Jumlah Sewa Sepeda')
plt.xlabel('Hari Libur')
plt.ylabel('Jumlah Sewa Sepeda')
plt.show()

# Visualisasi pengaruh akhir pekan terhadap jumlah sewa sepeda
plt.figure(figsize=(10, 6))
sns.barplot(x='workingday', y='cnt', data=data)
plt.title('Pengaruh Akhir Pekan terhadap Jumlah Sewa Sepeda')
plt.xlabel('Hari Kerja')
plt.ylabel('Jumlah Sewa Sepeda')
plt.show()

# Visualisasi pengaruh jam terhadap jumlah sewa sepeda
plt.figure(figsize=(10, 6))
sns.barplot(x='hr', y='cnt', data=data)
plt.title('Pengaruh Jam terhadap Jumlah Sewa Sepeda')
plt.xlabel('Jam')
plt.ylabel('Jumlah Sewa Sepeda')
plt.show()
# Out:
# C:\Users\LAUREN VALENTINA\AppData\Local\Temp\ipykernel_216\361854532.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = data.corr()['cnt'].drop('cnt')
# Korelasi antara fitur dan jumlah sewa sepeda:
# instant       0.278379
# season        0.178056
# yr            0.250495
# mnth          0.120638
# hr            0.394071
# holiday      -0.030927
# weekday       0.026900
# workingday    0.030284
# weathersit   -0.142426
# temp          0.404772
# atemp         0.400929
# hum          -0.322911
# windspeed     0.093234
# casual        0.694564
# registered    0.972151
# Name: cnt, dtype: float64

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1

# %% [raw]
# Bagaimana pola permintaan sewa sepeda dari waktu ke waktu (harian, mingguan, bulanan, musiman)?
#
# pola permintaan sewa sepeda harian menunjukan permintaan sewa meningkat pada pagi hari sekitar pukul 8-9 , dan akan menurun pada waktu siang hari.terjadi peningkatan permintaan saat sore hari dan akan sangat rendah saat malam hari
# pola permintaan sewa sepeda mingguan menunjukan permintaan sewa cendrung tinggi pada hari kerrja di bandingkan hari pekan, bahkan pada hari minggu permintaan sangat rendah sekali
# pola permintaan sewa sepeda bulanan menunjukan permintaan cendrung meningkat pada bulan musim panas(juni-agustus). dan menurun secara signifikan pada bulam musin dingin(desember-febuari)
# pola permintaan sewa sepeda musiman menunjukan permintaan sewa tinggi terjadi pada musim panas dan munurun saat musim dingin.

# %% [markdown]
# - Conclution pertanyaan 2

# %% [raw]
# Faktor-faktor apa saja yang mempengaruhi jumlah sewa sepeda (cuaca, hari libur, akhir pekan, jam kerja, dll)?
#
# faktor-faktor seperti cuaca, hari libur, akhir pekan, dan jam memiliki pengaruh yang signifikan terhadap jumlah sewa sepeda. Kondisi cuaca yang baik, hari libur, hari kerja, dan jam-jam sibuk seperti pagi dan sore hari cenderung meningkatkan permintaan sewa sepeda.
